# %%
# %load_ext autoreload
# %autoreload

import io
import os
import sys
import django
import glob
import json
import re
import requests
from IPython.core.debugger import set_trace
from pathlib import Path
from django.core.files.base import ContentFile
from rest_framework import serializers
from tqdm.notebook import tqdm
from google.cloud import vision
from google.cloud import storage
from PIL import Image, ImageSequence
from gensim.models import Doc2Vec
from IPython.core.debugger import set_trace
import IPython
import collections
from googletrans import Translator
from google.cloud import translate_v2 as translate

parentdir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parentdir)
django.setup()

import getch.models as m
from django.db.models import Q
from django.apps import apps
from django_currentuser.middleware import get_current_user

model_path = 'doc2vec.model'
d2v = Doc2Vec.load(model_path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.flager' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.genderlabel' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.agelabel' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.bodylabel' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.stylelabel' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.itemlabel' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.user_groups' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.user_user_permissions' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.user' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.profile' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.link' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.boo_genderlabels' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.boo_agelabels' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.boo_bodylabels' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.boo_stylelabels' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.boo_itemlabels' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.boo_links' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.boo' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.post' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.postvoteox' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.postvoteab' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.postqa' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.comment' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.commentpix' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.postpix' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/base.py:321: RuntimeWarning: Model 'getch.pix' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# [autoreload of getch.models failed: Traceback (most recent call last):
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/base/base.py", line 237, in _cursor
#     return self._prepare_cursor(self.create_cursor(name))
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/utils/asyncio.py", line 26, in inner
#     return func(*args, **kwargs)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/postgresql/base.py", line 236, in create_cursor
#     cursor = self.connection.cursor()
# psycopg2.InterfaceError: connection already closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     old_obj = getattr(old, key)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/utils/functional.py", line 61, in __get__
#     return self.fget(cls)
#   File "/Users/quantlab/Documents/GitHub/maskplay/getch/models.py", line 243, in guestboo
#     return cls.objects.get(id=GUESTBOO)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/manager.py", line 85, in manager_method
#     return getattr(self.get_queryset(), name)(*args, **kwargs)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/query.py", line 425, in get
#     num = len(clone)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/query.py", line 269, in __len__
#     self._fetch_all()
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/query.py", line 1308, in _fetch_all
#     self._result_cache = list(self._iterable_class(self))
# django.db.utils.InterfaceError: connection already closed
# ]
# [autoreload of getch.admin failed: Traceback (most recent call last):
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/base/base.py", line 237, in _cursor
#     return self._prepare_cursor(self.create_cursor(name))
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/utils/asyncio.py", line 26, in inner
#     return func(*args, **kwargs)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/postgresql/base.py", line 236, in create_cursor
#     cursor = self.connection.cursor()
# psycopg2.InterfaceError: connection already closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     old_obj = getattr(old, key)
#   File "/Users/quantlab/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/utils/functional.py", line 61, in __get__
#     return self.fget(cls)
#   File "/Users/quantlab/Documents/GitHub/maskplay/getch/models.py", line 243, in guestboo
#     return cls.objects.get(id=GUESTBOO)
# django.db.utils.InterfaceError: connection already closed
# ]

# %%
# django를 불러오면 아래를 굳이 부를필요 없는듯
# os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = os.path.abspath(os.path.join(os.getcwd(), 'sideb-proejct-0e33d8c0b0a9.json'))

# %%
def detect_labels(localpath=None, url=None, min_score=0.8):
    client = vision.ImageAnnotatorClient()

    if localpath:
        with io.open(localpath, 'rb') as image_file:
            content = image_file.read() 

        image = vision.Image(content=content)

    else:
        image = vision.Image()
        image.source.image_uri = url
        
        # 장고 이미지필드의 경우, 아래처럼도 가능
        # image = vision.Image(content=_post.pix.read())
    
    response = client.label_detection(image=image, max_results=50)
    labels = response.label_annotations
    labels = [label.description.lower() for label in labels if label.score>=min_score]
    #labels = [label.description.lower().replace(' ', '_') for label in labels]
    
    #return ', '.join(labels)
    return labels


client = translate.Client()

def tokenized(labels):
    #txt_src = ', '.join(labels)
    translated = client.translate(labels, source_language='en', target_language='ko')#['translatedText']
    _labels = [_lab.replace(' ', '_') for _lab in labels]
    _translated = [_trans['translatedText'].replace(' ', '') for _trans in translated]
    
    if 'sneakers' in _labels:
        _translated.append('스니커즈')
        
    return ', '.join(_labels + _translated)

# %%
# _post = m.Post.objects.select_subclasses()[0]; _post
# _post = m.PostVoteAB.objects.filter(pixlabel_a='장희령 스탈'); _post
# _post = m.PostVoteAB.objects.filter(pixlabel_a='Gyakusou')[0]; _post
# _post = m.PostQA.objects.get(text__contains='놈코어 브랜드'); _post
_post = m.PostQA.objects.first(); _post
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-50-a9ead930ae5f> in <module>
#       3 # _post = m.PostVoteAB.objects.filter(pixlabel_a='Gyakusou')[0]; _post
#       4 # _post = m.PostQA.objects.get(text__contains='놈코어 브랜드'); _post
# ----> 5 _post = m.PostQA.objects.first(); _post
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/query.py in first(self)
#     676     def first(self):
#     677         """Return the first object of a query or None if no match is found."""
# --> 678         for obj in (self if self.ordered else self.order_by('pk'))[:1]:
#     679             return obj
#     680
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/query.py in __iter__(self)
#     285                - Responsible for turning the rows into model objects.
#     286         """
# --> 287         self._fetch_all()
#     288         return iter(self._result_cache)
#     289
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/query.py in _fetch_all(self)
#    1306     def _fetch_all(self):
#    1307         if self._result_cache is None:
# -> 1308             self._result_cache = list(self._iterable_class(self))
#    1309         if self._prefetch_related_lookups and not self._prefetch_done:
#    1310             self._prefetch_related_objects()
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/model_utils/managers.py in __iter__(self)
#      37                 yield sub_obj
#      38         else:
# ---> 39             yield from iter
#      40
#      41
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/query.py in __iter__(self)
#      51         # Execute the query. This will also fill compiler.select, klass_info,
#      52         # and annotations.
# ---> 53         results = compiler.execute_sql(chunked_fetch=self.chunked_fetch, chunk_size=self.chunk_size)
#      54         select, klass_info, annotation_col_map = (compiler.select, compiler.klass_info,
#      55                                                   compiler.annotation_col_map)
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/models/sql/compiler.py in execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1154             cursor = self.connection.cursor()
#    1155         try:
# -> 1156             cursor.execute(sql, params)
#    1157         except Exception:
#    1158             # Might fail for server-side cursors (e.g. connection closed)
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      96     def execute(self, sql, params=None):
#      97         with self.debug_sql(sql, params, use_last_executed_query=True):
# ---> 98             return super().execute(sql, params)
#      99
#     100     def executemany(self, sql, param_list):
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      64
#      65     def execute(self, sql, params=None):
# ---> 66         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      67
#      68     def executemany(self, sql, param_list):
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      73         for wrapper in reversed(self.db.execute_wrappers):
#      74             executor = functools.partial(wrapper, executor)
# ---> 75         return executor(sql, params, many, context)
#      76
#      77     def _execute(self, sql, params, *ignored_wrapper_args):
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      88                 if dj_exc_type not in (DataError, IntegrityError):
#      89                     self.wrapper.errors_occurred = True
# ---> 90                 raise dj_exc_value.with_traceback(traceback) from exc_value
#      91
#      92     def __call__(self, func):
#
# ~/Documents/GitHub/maskplay/venv/lib/python3.8/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.

# %%
# path = '신발신발.png'
path = _post.pix
img = Image.open(path)
img.resize((int(img.width / 2), int(img.height / 2)))
# Out:
# <PIL.Image.Image image mode=RGBA size=499x499 at 0x7FA7786E2E20>

# %%
labels = detect_labels(url=_post.pix.url); labels
# Out:
# []

# %%
for _p in tqdm(m.PostQA.objects.order_by('-id')[65:100]):
    labels = detect_labels(url=_p.pix.url)
    
    pix = m.Pix()
    pix.owner = _p.boo
    pix.src = _p.pix
    pix.desc = _p.text
    pix.tokens = tokenized(labels) if len(labels)>0 else ''
    pix.save()
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]

# %%
m.PostQA.objects.order_by('-id')[65].text
# Out:
# '키큰여자 바지사이트 추천 좀 해줘ㅠㅠ 청바지를 주로 입는데 아니 요새는 발목 보이는 게 트렌드야?? 죄다 짧아서 못 입겠어... 추천좀해주라ㅠㅠ...\r\n'

# %%
# https://github.com/ssut/py-googletrans
# translator = Translator(service_urls=['translate.googleapis.com','translate.google.com','translate.google.co.kr'])
# result = translator.translate(det, src='en', dest="ko")
# result.text

# %% [markdown]
# # population

# %%
for p in tqdm(m.Post.objects.select_subclasses()):
    if p.type == 'postvoteox':
        tokens = detect_labels(url=p.pix.url)
        m.Postpix.objects.create(key='ox', post=p, img=p.pix, tokens=tokens)
        
    elif p.type == 'postvoteab':
        tokens_a = detect_labels(url=p.pix_a.url)
        tokens_b = detect_labels(url=p.pix_b.url)
        m.Postpix.objects.create(key='a', post=p, img=p.pix_a, tokens=tokens_a, desc=p.pixlabel_a)
        m.Postpix.objects.create(key='b', post=p, img=p.pix_b, tokens=tokens_b, desc=p.pixlabel_b)
# Out:
#   0%|          | 0/112 [00:00<?, ?it/s]

# %% [markdown]
# # testify

# %%
def preproc(text, remove_url=True, remove_mention=False, remove_hashtag=False):
    LINEBREAK = r'\n' # str.replace에서는 r'\n'으로 검색이 안된다
    RT = '((?: rt)|(?:^rt))[^ @]?'
    EMOJI = r'[\U00010000-\U0010ffff]'
    DOTS = '…'
    LONG_BLANK = r'[ ]+'
    SPECIALS = r'([^ a-zA-Z0-9_\u3131-\u3163\uac00-\ud7a3]+)|([ㄱ-ㅣ]+)'
    
    # \u3131-\u3163\uac00-\ud7a3 는 한글을 의미함
    # URL = r'(?P<url>(https?://)?(www[.])?[^ \u3131-\u3163\uac00-\ud7a3]+[.][a-z]{2,6}\b([^ \u3131-\u3163\uac00-\ud7a3]*))'
    URL1 = r'(?:https?:\/\/)?(?:www[.])?[^ :\u3131-\u3163\uac00-\ud7a3]+[.][a-z]{2,6}\b(?:[^ \u3131-\u3163\uac00-\ud7a3]*)'
    URL2 = r'pic.twitter.com/[a-zA-Z0-9_]+'
    URL = '|'.join((URL1, URL2))
    
    HASHTAG = r'#(?P<inner_hashtag>[^ #@]+)'
    MENTION = r'@(?P<inner_mention>[^ #@]+)' 
    
    text = text.lower()
    
    if remove_url:
        text = re.sub(URL, ' ', text)

    if remove_mention:
        text = re.sub(MENTION, ' ', text)        
    else:
        text = re.sub(MENTION, ' \g<inner_mention>', text)
        
    if remove_hashtag:
        text = re.sub(HASHTAG, ' ', text)
    else:
        text = re.sub(HASHTAG, ' \g<inner_hashtag>', text)
        
    text = re.sub('|'.join((LINEBREAK, RT, EMOJI, DOTS, SPECIALS)), ' ', text)
    return re.sub(LONG_BLANK, ' ', text).strip()

# %%
boo_id = 60
boo = m.Boo.objects.get(id=boo_id)
styletags = list(boo.styletags.values_list('tag', flat=True))
fashiontems = list(boo.fashiontems.values_list('item', flat=True))
baseid = preproc(boo.nick.lower() + ' ' + boo.text.lower()).split(' ') + styletags + fashiontems

print(styletags)
print(fashiontems)
print(baseid)
# Out:
# ['어깡', '역삼각형', '대두', '상비', '오버핏럽']
# ['팬츠', '아우터']
# ['미스터변', '옷잘입는남자', '어깡', '역삼각형', '대두', '상비', '오버핏럽', '팬츠', '아우터']

# %%
votes = m.Boo.objects.get(id=boo_id).voting_record

# %%
# pos = []
# neg = []

# for p in m.Post.objects.filter(pk__in=votes).prefetch_related('postpix_set').select_subclasses():
#     if p.type == 'postvoteab':
#         if votes[p.id] == 0:
#             pos += p.postpix_set.get(key='a').tokens.split(', ')
#             neg += p.postpix_set.get(key='b').tokens.split(', ')
            
#         else:
#             neg += p.postpix_set.get(key='a').tokens.split(', ')
#             pos += p.postpix_set.get(key='b').tokens.split(', ')

# %%
pos = []
neg = []

for pix in tqdm(m.Postpix.objects.filter(post_id__in=votes).select_related('post')):
    act = votes[pix.post.id]
    desc = preproc(pix.desc.lower()).split(' ') if pix.desc else []
    
    if pix.key=='ox' and act==0:
        pos += pix.tokens.split(', ') + desc
    
    elif pix.key=='ox' and act==1:
        neg += pix.tokens.split(', ') + desc
        
    elif (pix.key=='a' and act==0) or (pix.key=='b' and act==1):
        pos += pix.tokens.split(', ') + desc
        
    elif (pix.key=='a' and act==1) or (pix.key=='b' and act==0):
        neg += pix.tokens.split(', ') + desc
# Out:
#   0%|          | 0/158 [00:00<?, ?it/s]

# %%
len(pos), len(neg)
# Out:
# (826, 808)

# %%
list(dict((collections.Counter(pos) - collections.Counter(neg)).most_common(10)).keys())
# Out:
# ['footwear',
#  'style',
#  'athletic_shoe',
#  'sneakers',
#  'jacket',
#  'outerwear',
#  'wool',
#  'clothing',
#  'shoe',
#  'bag']

# %%
list(dict((collections.Counter(neg) - collections.Counter(pos)).most_common(10)).keys())
# Out:
# ['white',
#  'black',
#  'collar',
#  'standing',
#  'fur_clothing',
#  'active_shirt',
#  'pattern',
#  'formal_wear',
#  'uniform',
#  'clothes_hanger']

# %%
qry_pos = d2v.infer_vector(pos, epochs=500)
qry_neg = d2v.infer_vector(neg, epochs=500)
qry_baseid = d2v.infer_vector(baseid, epochs=500)
d2v.docvecs.most_similar(positive=[qry_pos, qry_baseid], negative=[qry_neg], topn=10)
# Out:
# [('eider', 0.42397236824035645),
#  ('barrel', 0.40111589431762695),
#  ('haveagoodtime', 0.37154486775398254),
#  ('barbour', 0.3517550826072693),
#  ('fillingpieces', 0.3487234115600586),
#  ('giordano', 0.34721603989601135),
#  ('billylosangeles', 0.3421420454978943),
#  ('mizuno', 0.33944040536880493),
#  ('birkenstock', 0.33681154251098633),
#  ('critic', 0.3367672562599182)]

# %%
qry_pos = d2v.infer_vector(pos, epochs=500)
qry_neg = d2v.infer_vector(neg, epochs=500)
qry_baseid = d2v.infer_vector(baseid, epochs=500)
d2v.wv.most_similar(positive=[qry_pos, qry_baseid], negative=[qry_neg], topn=10)
# Out:
# [('듣자', 0.4584624767303467),
#  ('별보러', 0.43226414918899536),
#  ('우비', 0.42545634508132935),
#  ('아리랑', 0.41935038566589355),
#  ('꽃길', 0.41245749592781067),
#  ('어여쁘고', 0.4106650948524475),
#  ('광고인지', 0.41063159704208374),
#  ('으아아', 0.4104529023170471),
#  ('박보검뮤직비디오', 0.4103260040283203),
#  ('사람', 0.4098772406578064)]

# %%
d2v.wv.vocab['기본']

# %%
qry_vec = d2v.infer_vector(labels, epochs=500)
d2v.docvecs.most_similar(positive=[qry_vec], topn=10)
# Out:
# [('acronym', 0.8029796481132507),
#  ('acoldwall', 0.7641227841377258),
#  ('gyakusou', 0.7501798868179321),
#  ('y3', 0.7264542579650879),
#  ('visvim', 0.7249417304992676),
#  ('1017alyx9sm', 0.7163081169128418),
#  ('undefeated', 0.7145105600357056),
#  ('offwhite', 0.7137323617935181),
#  ('onitsukatiger', 0.7095181345939636),
#  ('undercover', 0.7080243825912476)]

# %%
qry_vec = d2v.infer_vector(labels, epochs=500)
d2v.wv.most_similar(positive=[qry_vec], topn=10)
# Out:
# [('에어조던5', 0.8540251851081848),
#  ('토로', 0.8507999181747437),
#  ('가능하시구요', 0.8153282403945923),
#  ('나이키매니아', 0.8092210292816162),
#  ('클릿슈즈', 0.8091098666191101),
#  ('멕시코66', 0.8079787492752075),
#  ('르브론x', 0.8074090480804443),
#  ('모어업템포', 0.8069274425506592),
#  ('풋락커', 0.8063082695007324),
#  ('폼포짓', 0.8038229942321777)]

# %%
qry_vec = d2v.infer_vector(['어깡'], epochs=500)
d2v.docvecs.most_similar(positive=[qry_vec], topn=10)
# Out:
# [('gucci', 0.07552319765090942),
#  ('louisvuitton', 0.06907099485397339),
#  ('kenzo', 0.06679679453372955),
#  ('prada', 0.06515025347471237),
#  ('bally', 0.06012149155139923),
#  ('fendi', 0.04744155704975128),
#  ('gentlemonster', 0.0444667786359787),
#  ('eider', 0.04029855877161026),
#  ('tomford', 0.03858783841133118),
#  ('paulsmith', 0.03504317253828049)]

# %%
qry_vec = d2v.infer_vector([boo.nick], epochs=500)
d2v.wv.most_similar(positive=[qry_vec], topn=10)
# Out:
# [('송일국', 0.30594557523727417),
#  ('승부사', 0.2758767008781433),
#  ('신서유기', 0.27055495977401733),
#  ('팔아야귀국', 0.2643117904663086),
#  ('기리', 0.25868964195251465),
#  ('아들', 0.24789908528327942),
#  ('민낯', 0.24750250577926636),
#  ('중국', 0.24671602249145508),
#  ('무시하는', 0.24649766087532043),
#  ('수거', 0.24602524936199188)]
