# %%
from PIL import Image, ImageSequence

# %%
img1 = Image.open('mask2.png')

# %%
img2 = Image.open('killyou.gif')

# %%
frames = []
for frame in ImageSequence.Iterator(img2):
    frame = frame.copy()
#     frame.paste(img1, mask=img1)
    frames.append(frame)
    
frames[0].save('output.gif', save_all=True, append_images=frames[1:])

# %%
frames[2]
# Out:
# <PIL.Image.Image image mode=P size=400x242 at 0x20FFD50C390>

# %% [markdown]
# ![SegmentLocal](output.gif "segment")
